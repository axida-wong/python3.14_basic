# %%
# 更复杂的输出格式

# 格式化字符串, f-string
year = 2026
event = 'Referendum'
print(f'Result of the {year} {event}')

# str.format()方法
yes_votes = 42_572_654
total_votes = 85_705_149
percentage = yes_votes / total_votes
print("{:-9} YES votes {:2.2%}".format(yes_votes, total_votes))
# Out:
# Result of the 2026 Referendum
#  42572654 YES votes 8570514900.00%

# %%
# 如果不需要花哨的输出，只想快速显示变量进行调试，
# 可以用 repr() 或 str() 函数把值转化为字符串。

# repr() 把一个 Python 对象“以程序员看得懂、尽可能能还原对象的形式”表示出来。
# 返回一个字符串 representation

# str() 函数返回供人阅读的值，repr() 则生成适于解释器读取的值 (如果没有等效的
# 语法，则强制引发 SyntaxError)。

s = 'Hello, world.'
print(str(s))
print (repr(s))
print(str(1/7))
x = 10 * 3.25
y = 200 * 200
s = 'The value of x is ' + repr(x) + ', and y is ' + repr(y) + '...'
print(s)
hello = 'hello, world\n'
hellos = repr(hello)
print(hellos)
for i in hellos:
    print(i, end=' ')
print()
# repr() 的参数是可以任何python对象
print(repr((x, y, ('spam', 'eggs'))))
# Out:
# Hello, world.
# 'Hello, world.'
# 0.14285714285714285
# The value of x is 32.5, and y is 40000...
# 'hello, world\n'
# ' h e l l o ,   w o r l d \ n '
# (32.5, 40000, ('spam', 'eggs'))

# %%
# 格式化字符串字面量

# 格式说明符是可选的，写在表达式后面，可以更好地控制格式化值的方式
import math
print(f"The value of pi is aproximately {math.pi:.3f}")
# Out:
# The value of pi is aproximately 3.142

# %%
# 在 ':' 后传递整数，为该字段设置最小字符宽度，常用于列对齐

table = {"Sjoerd": 4127, "Jack": 4098, "Dcab": 7678}
for name, phone in table.items():
    print(f"{name:10} ==> {phone: 10d}")
# Out:
# Sjoerd     ==>       4127
# Jack       ==>       4098
# Dcab       ==>       7678

# %%
# 还有一些修饰符可以在格式化前转换值。 
# '!a' 应用 ascii() ，'!s' 应用 str()，'!r' 应用 repr()：

animals = 'eels'
print(f"My hovercraft is full of {animals}.")
print(f"My hovercraft is full of {animals!r}")
# Out:
# My hovercraft is full of eels.
# My hovercraft is full of 'eels'

# %%
# = 说明符可被用于将一个表达式扩展为表达式文本、
# 等号再加表达式求值结果的形式。

bugs = 'roahes'
count = 13
area = 'living room'
print(F"Debugging {bugs=}, {count=}, {area}")
# Out:
# Debugging bugs='roahes', count=13, living room

# %%
# 字符串format()方法

print("We are the {} who say \"{}\"".format('knights', 'Ni'))
# Out:
# We are the knights who say "Ni"

# %%
# 花括号中的数字表示传递给 str.format() 方法的对象所在的位置。
print('{0} and {1}'.format('spam', 'eggs'))
print('{1} and {0}'.format('spam', 'eggs'))
# Out:
# spam and eggs
# eggs and spam

# %%
# str.format() 方法中使用关键字参数名引用值。

print('This {food} is {adjective}.'.format(
    food='spam', adjective='absolutely horrible'
))
# Out:
# This spam is absolutely horrible.

# %%
# 位置参数和关键字参数可以任意组合

print('The story of {0}, {1}, and {other}.'.format(
    'Bill', 'Manfred', other='Georg'))
# Out:
# The story of Bill, Manfred, and Georg.

# %%
# 如果不想分拆较长的格式字符串，最好按名称引用变量进行格式化，不要按位置。
# 这项操作可以通过传递字典，并用方括号 '[]' 访问键来完成。

table = {'Sjoerd': 4127, 'Jack': 4098, 'Dcab': 8637678}
print('Jack: {0[Jack]:d}; Sjoerd: {0[Sjoerd]:d}; '
      'Dcab: {0[Dcab]:d}'.format(table))
# Out:
# Jack: 4098; Sjoerd: 4127; Dcab: 8637678

# %%
# 这也可以通过将 table 字典作为采用 ** 标记的关键字参数传入来实现。
print("Jack: {Jack:d}; Sjoerd: {Sjoerd:d}; Dcab: {Dcab:d}".format(**table))
# Out:
# Jack: 4098; Sjoerd: 4127; Dcab: 8637678

# %%
# vars 函数 vars(obj) 就是查看对象内部属性字典 obj.__dict__ 的快捷方式。

class Person:
    pass

p = Person()
p.name = "Ash"
p.age = 23

print(p.__dict__)
# 因为实例对象内部有一个属性字典：
# p
# |
# ├── __dict__
# |       |
# |       ├── name → "Ash"
# |       └── age  → 23

vars(p) == p.__dict__
# 这两个等价
# Out:
# {'name': 'Ash', 'age': 23}
# True

# %%
# 与内置函数 vars() 一同使用时这种方式非常实用，
# 它将返回一个包含所有局部变量的字典

table = {k: str(v) for k, v in vars().items()}
message = " ".join([f"{k}: " + "{" + k + "}" for k in table.keys()])
print(table)
print(message)
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': 'None', '__loader__': 'None', '__spec__': 'None', '__builtin__': "<module 'builtins' (built-in)>", '__builtins__': "<module 'builtins' (built-in)>", '_ih': '[\'\', \'# 更复杂的输出格式\\n\\n# 格式化字符串, f-string\\nyear = 2026\\nevent = \\\'Referendum\\\'\\nprint(f\\\'Result of the {year} {event}\\\')\\n\\n# str.format()方法\\nyes_votes = 42_572_654\\ntotal_votes = 85_705_149\\npercentage = yes_votes / total_votes\\nprint("{:-9} YES votes {:2.2%}".format(yes_votes, total_votes))\', "# 如果不需要花哨的输出，只想快速显示变量进行调试，\\n# 可以用 repr() 或 str() 函数把值转化为字符串。\\n\\n# repr() 把一个 Python 对象“以程序员看得懂、尽可能能还原对象的形式”表示出来。\\n# 返回一个字符串 representation\\n\\n# str() 函数返回供人阅读的值，repr() 则生成适于解释器读取的值 (如果没有等效的\\n# 语法，则强制引发 SyntaxError)。\\n\\ns = \'Hello, world.\'\\nprint(str(s))\\nprint (repr(s))\\nprint(str(1/7))\\nx = 10 * 3.25\\ny = 200 * 200\\ns = \'The value of x is \' + repr(x) + \', and y is \' + repr(y) + \'
# ...

# %%
# 举个例子，以下几行代码将产生一组整齐的数据列，包含给定的整数及其平方与立方

l = []
for x in range(1, 11):
    l.append("{0:2d} {1:3d} {2:4d}".format(x, x * x, x * x * x))

l
# Out:
# [' 1   1    1',
#  ' 2   4    8',
#  ' 3   9   27',
#  ' 4  16   64',
#  ' 5  25  125',
#  ' 6  36  216',
#  ' 7  49  343',
#  ' 8  64  512',
#  ' 9  81  729',
#  '10 100 1000']

# %%
# 下面是使用手动格式化方式实现的同一个平方和立方的表：
for x in range(1, 11):
    print(repr(x).rjust(2), repr(x * x).rjust(3), end = ' ')
    print(repr(x * x * x).rjust(4))

# 字符串对象的 str.rjust() 方法通过在左侧填充空格，对给定宽度字段中的
# 字符串进行右对齐。同类方法还有 str.ljust() 和 str.center() 。这些
# 方法不写入任何内容，只返回一个新字符串，如果输入的字符串太长，它们不
# 会截断字符串，而是原样返回；虽然这种方式会弄乱列布局，但也比另一种方
# 法好，后者在显示值时可能不准确（如果真的想截断字符串，可以使用 x.ljust(n)[:n] 
# 这样的切片操作 。）
# Out:
#  1   1    1
#  2   4    8
#  3   9   27
#  4  16   64
#  5  25  125
#  6  36  216
#  7  49  343
#  8  64  512
#  9  81  729
# 10 100 1000

# %%
# 读写文件

# open() 返回一个 file object ，最常使用的是两个位置参数和一个关键字参数：

# open(filename, mode, encoding=None)
# 在文本模式下读取文件时，默认把平台特定的行结束符 (Unix 上为 \n, Windows 上
# 为 \r\n) 转换为 \n。 在文本模式下写入数据时，默认把 \n 转换回平台特定结束符。 
# 这种操作方式在后台修改文件数据对文本文件来说没有问题，但会破坏 JPEG 或 EXE 
# 等二进制文件中的数据。 注意，在读写此类文件时，一定要使用二进制模式。

# with 关键字啥意思
# “进入 A 管理的环境，把进入后的对象叫 B，在里面执行 C，出来以后自动清理。”

with open('workfile', 'r', encoding="utf-8") as f:
    read_data = f.read()

# 我们可以检测文件是否已被自动关闭
f.closed

print(read_data)
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
# 调用 f.write() 时，未使用 with 关键字，或未调用 f.close()，即使程序正常退出，也**可能** 
# 导致 f.write() 的参数没有完全写入磁盘。

f = open('workfile')
f.close()
# f.read()

# %%
# 文件对象的方法

f = open('workfile')

# f.read(size) 可用于读取文件内容，它会读取一些数据，并返回字符串（文本模式），或字节串对象（在二进制模式下）。
# size 是可选的数值参数。省略 size 或 size 为负数时，读取并返回整个文件的内容；文件大小是内存的两倍时，会出现
# 问题。size 取其他值时，读取并返回最多 size 个字符（文本模式）或 size 个字节（二进制模式）。如已到达文件末尾，
# f.read() 返回空字符串 ('')。

print(f.read())
print()
print(repr(f.read()))
# Out:
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
#
# ''

# %%
f.seek(0)
print(f.readline()) # readline method 保留文件末尾换行符
print(repr(f.readline()))
# Out:
# Beautiful is better than ugly.
#
# 'Explicit is better than implicit.\n'

# %%
lines = []
# 从文件中读取多行时，可以用循环遍历整个文件对象。这种操作能高效利用内存，快速，且代码简单：
for line in f:
    lines.append(line)

# print(lines)
for i in lines:
    print(i)
print(f.readline() == '')
# Out:
# Simple is better than complex.
#
# Complex is better than complicated.
#
# Flat is better than nested.
#
# Sparse is better than dense.
#
# Readability counts.
#
# Special cases aren't special enough to break the rules.
#
# Although practicality beats purity.
#
# Errors should never pass silently.
#
# Unless explicitly silenced.
#
# In the face of ambiguity, refuse the temptation to guess.
#
# There should be one-- and preferably only one --obvious way to do it.
#
# Although that way may not be obvious at first unless you're Dutch.
#
# Now is better than never.
#
# Although never is often better than *right* now.
#
# If the implementation is hard to explain, it's a bad idea.
#
# If the implementation is easy to explain, it may be a good idea.
#
# Namespaces are one honking great idea -- let's do more of those!
# True

# %%
# 如需以列表形式读取文件中的所有行，可以用 list(f) 或 f.readlines()。

f.close()

with open('workfile') as f:
    lines = list(f)
    print(lines)
    # for i in lines:
        # print(repr(i))

print()

with open('workfile') as f:
    lines = f.readlines()
    # print(lines)
    for i in lines:
        print(repr(i))
# Out:
# ['Beautiful is better than ugly.\n', 'Explicit is better than implicit.\n', 'Simple is better than complex.\n', 'Complex is better than complicated.\n', 'Flat is better than nested.\n', 'Sparse is better than dense.\n', 'Readability counts.\n', "Special cases aren't special enough to break the rules.\n", 'Although practicality beats purity.\n', 'Errors should never pass silently.\n', 'Unless explicitly silenced.\n', 'In the face of ambiguity, refuse the temptation to guess.\n', 'There should be one-- and preferably only one --obvious way to do it.\n', "Although that way may not be obvious at first unless you're Dutch.\n", 'Now is better than never.\n', 'Although never is often better than *right* now.\n', "If the implementation is hard to explain, it's a bad idea.\n", 'If the implementation is easy to explain, it may be a good idea.\n', "Namespaces are one honking great idea -- let's do more of those!"]
#
# 'Beautiful is better than ugly.\n'
# 'Explicit is better than implicit.\n'
# ...

# %%
# f.write(string) # 把 string 里的内容写入文件，并返回写入的字符数

with open('writefile', 'w') as f:
    c = f.write("This is a test\n")
    print(c)

# 写入其他类型的对象前，要先把它们转化为字符串（文本模式）或字节对象（二进制模式）：
    value = ('the answer', 42)
    s = str(value)
    f.write(s)
# Out:
# 15

# %%
# f.tell() 返回整数，给出文件对象在文件中的当前位置，表示为二进制模式下时
# 从文件开始的字节数，以及文本模式下的意义不明的数字。

# f.seek(offset, whence) 可以改变文件对象的位置。通过向参考点添加 offset 
# 计算位置；参考点由 whence 参数指定。 whence 值为 0 时，表示从文件开头计
# 算，1 表示使用当前文件位置，2 表示使用文件末尾作为参考点。省略 whence 时，
# 其默认值为 0，即使用文件开头作为参考点。

# whence 0 文件开头位置
# whence 1 当前位置
# whence 2 文件末尾

# b-tring: 以 b 开头的字符串字面量，表示 bytes（字节序列），而
#          不是普通的 str 文本。

with open("tell_and_seek", "rb+") as f:
    f.write(b'0123456789abcdef')

    f.seek(5) # 定位到文件中的第六个字节
    print(f.read(1))
    f.seek(-3, 2)
    print(f.read(1))
    print(f.tell())
    print("*" * 14)
    print('0123456789abcdef')
# Out:
# b'5'
# b'd'
# 14
# **************
# 0123456789abcdef

# %%
# 使用JSON保存结构化数据

# 只需一行简单的代码即可查看某个对象的 JSON 字符串表现形式：

import json
x = [1, 'simple', 'list']
# dump 转储， s string 字符串
# 转储成字符串
print(json.dumps(x))

# dumps() 函数还有一个变体， dump() ，它只将对象序列化为 text file 。
# 因此，如果 f 是 text file 对象，可以这样做：

with open('jsonfile.json', "w") as f:
    json.dump(x, f)

with open('jsonfile.json', "r") as f:
    x = json.load(f)
    print(type(x), x)
# Out:
# [1, "simple", "list"]
# <class 'list'> [1, 'simple', 'list']
