# %%
# while

# if

x = int(input("Please enter an integer: "))

if x < 0:
    x = 0
    print("Negative changed to zero.")
elif x == 0:
    print("zero")
elif x == 1:
    print("single")
else:
    print("none")
# Out:
# none

# %%
# for

words = ['cat', 'window', 'defenestrate']

for w in words:
    print(w, len(w))
# Out:
# cat 3
# window 6
# defenestrate 12

# %%
# 创建示例多项集
users = {'Hans': 'active', 'Éléonore': 'inactive', '景太郎': 'active'}

# 策略：迭代一个副本
for user, status in users.copy().items():
    if status == 'inactive':
        del users[user]

print(users)

# 策略：创建一个新多项集
# items 方法返回一个包含所有键值对的可迭代对象
active_users = {}
for user, status in users.items():
    if status == 'active':
        active_users[user] = status

print(active_users)
# Out:
# {'Hans': 'active', '景太郎': 'active'}
# {'Hans': 'active', '景太郎': 'active'}

# %%
# range(), 用于生成等差数列

for i in range(5):
    print(i)

print()
print(list(range(-10, 11, 2)))

# range() 与 len() 组合使用
a = ['mary', 'had', 'a', 'little', 'lamb']
for i in range(len(a)):
    print(i, a[i], sep=', ')

range(10)
# Out:
# 0
# 1
# 2
# 3
# 4
#
# [-10, -8, -6, -4, -2, 0, 2, 4, 6, 8, 10]
# 0, mary
# 1, had
# 2, a
# 3, little
# 4, lamb
# range(0, 10)

# %%
# break and continue, same as C

# %%
# 循环的else子句
# 在 for 或 while 循环中 break 语句可能对应一个 else 子句。 
# 如果循环在未执行 break 的情况下结束，else 子句将会执行。

for n in range(2, 10):
    for x in range(2, n):
        if n % x == 0:
            print(n, 'equals', x, '*', n // x)
            break
    else:
        print(n, 'is a prime number')
# Out:
# 2 is a prime number
# 3 is a prime number
# 4 equals 2 * 2
# 5 is a prime number
# 6 equals 2 * 3
# 7 is a prime number
# 8 equals 2 * 4
# 9 equals 3 * 3

# %%
# pass 语句

# while True:
    # pass

# 创建最小的类
class MyEmptyClass:
    pass

# 语句主体的占位符
def initlog(*args):
    pass

# %%
# match 语句, 类似与switch

def http_error(status):
    match status:
        case 400:
            return "Bad request"
        case 404:
            return "Not found"
        case 418:
            return "I'm a teapot"
        case 401 | 403 | 405:
            return "Not allowed"
        case _: # _ 通配符
            return "Something's wrong with the internet"

# %%
# | 多个字面值组合到一个模式

for i in [400, 401, 402, 403, 405, 406]:
    print(i, http_error(i))
# Out:
# 400 Bad request
# 401 Not allowed
# 402 Something's wrong with the internet
# 403 Not allowed
# 405 Not allowed
# 406 Something's wrong with the internet

# %%
# 形如解包赋值的模式可被用于绑定变量
# point 是一个 (x, y) 元组
points = []
points.append((0, 0))
points.append((0, 6)) 
points.append((0, 6)) 
points.append((6, 6)) 
points.append('not')

print(points)

for i in points:
    match i:
        case (0, 0):
            print("Origin")
        case (0, y):
            print(f"Y={y}")
        case (x, 0):
            print(f"X={x}")
        case (x, y):
            print(f"X={x}, Y={y}")
        case _:
            # raise ValueError("Not a point")
            print("Not a point")
# Out:
# [(0, 0), (0, 6), (0, 6), (6, 6), 'not']
# Origin
# Y=6
# Y=6
# X=6, Y=6
# Not a point

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

def where_is(point):
    match point:
        case Point(x=0, y=0):
            print("Origin")
        case Point(x=0, y=y):
            print(f"Y={y}")
        case Point(x=x, y=0):
            print(f"X={x}")
        case Point():
            print("Somewhere else")
        case _:
            print("Not a point")

# %%
# Point(1, var) 找一个 Point，要求 x == 1，然后把它的 y 放进变量 var
# Point(1, y=var) 因为我们定义了：__match_args__ = ("x", "y"), 所以等价

# Point(x=1, y=var)
# Point(y=var, x=1)

# Point(1, var) 这种的就需要位置匹配了

# 这些完全等价

# %%
class Point:
    __match_args__ = ('x', 'y')
    def __init__(self, x, y):
        self.x = x
        self.y = y

match points:
    case []:
        print("No points")
    case [Point(0, 0)]:
        print("The origin")
    case [Point(x, y)]:
        print(f"Single point {x}, {y}")
    case [Point(0, y1), Point(0, y2)]:
        print(f"Two on the Y axis at {y1}, {y2}")
    case _:
        print("Something else")
# Out:
# Something else

# %%
# 我们可以为模式添加 if 作为守卫子句。
# 如果守卫子句的值为假，那么 match 会继续尝试匹配下一个 case 块。
# 注意是先将值捕获，再对守卫子句求值：

point = Point(5, 5)
match point:
    case Point(x, y) if x == y:
        print(f"Y=X at {x}")
    case Point(x, y):
        print(f"Not on the diagonal")
# Out:
# Y=X at 5

# %%
# Python 原本的 *rest / **rest 解包语法

# 1. *rest：把剩下的“元素”收集起来

a, b, *rest = [1, 2, 3, 4, 5]
print((a, b, rest))
a, *rest, b = [1, 2, 3, 4, 5]
print((a, b, rest))

# 2. * 还有一个相反方向的用法：把东西“拆开”

def add(a, b, c):
    return a + b + c

add(*rest) # 这里的 * 把一个序列拆成一个个位置参数。
# Out:
# (1, 2, [3, 4, 5])
# (1, 5, [2, 3, 4])
# 9

# %%
# 3. **rest：专门针对字典

data = {
    "name": "Ash",
    "age": 23,
    "city": "Tokyo"
}

# ** 是给字典的 key-value 对用的

def person(name, age, city):
    print(name, age, city)

person(**data) # 把字典拆成一个个关键字参数, 就是类似于 name="Ash"这种的

# 4. ** 也可以用来“收集”关键字参数

def person(**kwargs):
    print(kwargs, type(kwargs))

person(name="Ash", age=23, city="Tokyo")
# Out:
# Ash 23 Tokyo
# {'name': 'Ash', 'age': 23, 'city': 'Tokyo'} <class 'dict'>

# %%
# x is None

# == 值相等 “x 和 y 里面装的东西一样吗？”

a = [1, 2, 3]
b = [1, 2, 3]

print(a == b)

# is 比较的是是不是同一个对象
print(a is b)

# 那为什么 None 要用 is？

# 因为 None 是 Python 中的一个单例对象（singleton）。
# 整个 Python 程序里，正常情况下就只有一个 None 对象。
c = None
print(c is None) # 用这个比较稳妥
print(c == None) # 但是 == 会调用对象的相等性比较机制，也就是可能调用：
                 # x.__eq__(None) 所以理论上，一个奇怪的自定义类可以让：
                 # some_object == None 返回： True
# Out:
# True
# False
# True
# True

# %%
# case语句还有一些关键特性

# 与解包赋值类似，元组和列表模式具有完全相同的含义并且实际上都能匹配任意序列，
# 区别是它们不能匹配迭代器或字符串。

# 序列模式支持扩展解包：[x, y, *rest] 和 (x, y, *rest) 和相应的解包赋值做
# 的事是一样的。接在 * 后的名称也可以为 _，所以 (x, y, *_) 匹配含至少两项的
# 序列，而不必绑定剩余的项。

# 映射模式：{"bandwidth": b, "latency": l} 从字典中捕获 "bandwidth" 和 
# "latency" 的值。额外的键会被忽略，这一点与序列模式不同。**rest 这样的解包
# 也支持。（但 **_ 将会是冗余的，故不允许使用。）

# case (Point(x1, y1), Point(x2, y2) as p2): ...
# 将把输入中的第二个元素捕获为 p2 （只要输入是包含两个点的序列）

# 大多数字面值是按相等性比较的，但是单例对象 True、False 和 None 则是按 id 
# 比较的。

# 模式可以使用具名常量。 它们必须为带点号的名称以防止它们被解读为捕获变量:
# 这里的“具名常量”其实就是一个翻译得有点吓人的词。你把它拆成：有名字的、不会变
# 的固定值

from enum import Enum
class Color(Enum):
    RED = 'red'
    GREEN = 'green'
    BLUE = 'blue'

color = Color(input("Enter your choise of 'red', 'blue', or 'green': "))

match color:
    case Color.RED:
        print("I see read!")
    case Color.GREEN:
        print("I see green!")
    case Color.BLUE:
        print("I see blue!")

# RED = "red"

# color = "red"

# match color:
#     case RED:
#         print("red")
# Python 会把 RED 当成一个捕获变量。
# 那什么叫“带点号的名称”？
# Color.RED 就是一个具名常量。

#   Color  → 类
#   .
#   RED    → 这个类里面的固定成员
# Out:
# I see blue!
